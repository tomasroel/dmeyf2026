# %% [markdown]
# <a href="https://colab.research.google.com/github/tomasroel/dmeyf2026/blob/main/ensembles/z4941_tareahogar_04_Trabajado_TR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# ##  1. Big Picture

# %% [markdown]
# LightGBM es el algoritmo estado del arte para datasets estructurados.
# <br> La Bayesian Optimization es el estado del arte para optimización de hiperparámetros
# <br> Las soluciones a las tres competencias de la asignatura contendrán LightGBMs y Bayesian Optimizations
# <br> LightGBM ha aumentado en forma no darwiniana sus hiperparámetros en los últimos ocho años; no todos los existentes son útiles.
# <br> Es necesario lograr entender cuales son los hiperparámetros relevantes de LightGBM

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# ### Estrategia de Exploración

# %% [markdown]
# Se utilizará la siguiente estrategia de optimización:
#
# En primer lugar, se dejarán fijos los siguientes parámetros:
#
# *   `max_depth = -1` — el crecimiento del árbol ya lo controla `num_leaves`
# *   `boosting = "gbdt"`
# *    `objective = "binary"`
# *    `min_sum_hessian_in_leaf` — bajarlo a ~0.001, si no bloquea hojas chicas junto con el desbalance

# %% [markdown]
# En la segunda corrida, se irá por la optimización de todos los parámetros de 'capacidad del modelo' en conjunto.
#
#
#
# *   num_leaves
# *   min_data_in_leaf
# *   learning_rate
# *   feature_fraction
# *   lambda_l1
# *   lambda_l2
# *   min_gain_to_split

# %% [markdown]
# ## 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dmeyf"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dmeyf" /content/buckets/b1


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/dmeyf2026-9c6f/competencia_01_crudo.csv"
archivo_destino="/content/datasets/competencia_01_crudo.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/competencia_01_crudo.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ## Generacion de la clase_ternaria

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %%
require( "data.table" )

# leo el dataset
dataset <- fread("/content/datasets/competencia_01_crudo.csv" )

# calculo el periodo0 consecutivo
dsimple <- dataset[, list(
    "pos" = .I,
    numero_de_cliente,
    periodo0 = as.integer(foto_mes/100)*12 +  foto_mes%%100 ) ]


# ordeno
setorder( dsimple, numero_de_cliente, periodo0 )

# calculo topes
periodo_ultimo <- dsimple[, max(periodo0) ]
periodo_anteultimo <- periodo_ultimo - 1


# calculo los leads de orden 1 y 2
dsimple[, c("periodo1", "periodo2") :=
    shift(periodo0, n=1:2, fill=NA, type="lead"),  numero_de_cliente ]

# assign most common class values = "CONTINUA"
dsimple[ periodo0 < periodo_anteultimo, clase_ternaria := "CONTINUA" ]

# calculo BAJA+1
dsimple[ periodo0 < periodo_ultimo &
    ( is.na(periodo1) | periodo0 + 1 < periodo1 ),
    clase_ternaria := "BAJA+1" ]

# calculo BAJA+2
dsimple[ periodo0 < periodo_anteultimo & (periodo0+1 == periodo1 )
    & ( is.na(periodo2) | periodo0 + 2 < periodo2 ),
    clase_ternaria := "BAJA+2" ]


# pego el resultado en el dataset original y grabo
setorder( dsimple, pos )
dataset[, clase_ternaria := dsimple$clase_ternaria ]

fwrite( dataset,
    file =  "/content/datasets/competencia_01.csv.gz",
    sep = ","
)
# Out:
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:base’:
#
#     %notin%

# %%
setorder( dataset, foto_mes, clase_ternaria, numero_de_cliente)
dataset[, .N, list(foto_mes, clase_ternaria)]
# Out:
#    foto_mes clase_ternaria N
# 1  202103   BAJA+1           1019
# 2  202103   BAJA+2            960
# 3  202103   CONTINUA       160921
# 4  202104   BAJA+1            964
# 5  202104   BAJA+2           1139
# 6  202104   CONTINUA       161181
# 7  202105   BAJA+1           1143
# 8  202105   BAJA+2            870
# 9  202105   CONTINUA       161755
# 10 202106   BAJA+1            874
# 11 202106   BAJA+2           1098
# 12 202106   CONTINUA       162142
# 13 202107   NA             163245
# 14 202107   BAJA+1           1103
# 15 202108   NA             164647

# %% [markdown]
# ## 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Mon Sep 07 07:16:21 PM 2026"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb)   max used  (Mb)
# Ncells  741504 39.7   1473300    78.7   1473300   78.7
# Vcells 1391539 10.7 170859661  1303.6 212615883 1622.2

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %% [markdown]
# Esta parte lleva varios minutos la primera vez en Google Colab

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if(!require("R.utils")) install.packages("R.utils")
require("R.utils")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: parallel
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings
#
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 4941
PARAM$semilla_primigenia <- 911341

# %%
# training y future
PARAM$train <- c(202104)
PARAM$train_final <- c(202104)
PARAM$future <- c(202106)
PARAM$semilla_kaggle <- 314159
PARAM$cortes <- seq(4000, 19000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.1

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  early_stopping_rounds= 200L,   # Early Stopping. Nuevo, agregado. Frena el algoritmo si pasan 200 rondas sin mejorar el AUC
  num_iterations= 2048L,         # <- funciona como techo. No siempre se hacen esta cantidad de iteraciones.
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  # los 4 de la primera corrida, mismos rangos
  makeNumericParam("learning_rate",     lower= 0.01, upper= 0.1),
  makeNumericParam("feature_fraction",  lower= 0.3,  upper= 0.7),
  makeIntegerParam("num_leaves",        lower= 50L,   upper= 1000L),
  makeIntegerParam("min_data_in_leaf",  lower= 50L,   upper= 3000L),

  # los 3 nuevos, en escala logaritmica
  makeNumericParam("lambda_l1",         lower= -3, upper= 2,
                   trafo= function(x) ifelse(x <= -2.9, 0, 10^x)),
  makeNumericParam("lambda_l2",         lower= -3, upper= 2,
                   trafo= function(x) ifelse(x <= -2.9, 0, 10^x)),
  makeNumericParam("min_gain_to_split", lower= -3, upper= 1,
                   trafo= function(x) ifelse(x <= -2.9, 0, 10^x))
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 80 # iteraciones bayesianas

# %%
# particionar agrega una columna llamada fold a un dataset
#   que consiste en una particion estratificada segun agrupa
# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(data, division, agrupa= "", campo= "fold", start= 1, seed= NA) {
  if (!is.na(seed)) set.seed(seed, "L'Ecuyer-CMRG")

  bloque <- unlist(mapply(
    function(x, y) {rep(y, x)},division, seq(from= start, length.out= length(division))))

  data[, (campo) := sample(rep(bloque,ceiling(.N / length(bloque))))[1:.N],by= agrupa]
}

# %%
# iniciliazo el dataset de realidad, para medir ganancia
realidad_inicializar <- function( pfuture, pparam) {

  # datos para verificar la ganancia
  drealidad <- pfuture[, list(numero_de_cliente, foto_mes, clase_ternaria)]

  particionar(drealidad,
    division= c(3, 7),
    agrupa= "clase_ternaria",
    seed= PARAM$semilla_kaggle
  )

  return( drealidad )
}

# %%
# evaluo ganancia en los datos de la realidad

realidad_evaluar <- function( prealidad, pprediccion) {

  prealidad[ pprediccion,
    on= c("numero_de_cliente", "foto_mes"),
    predicted:= i.Predicted
  ]

  tbl <- prealidad[, list("qty"=.N), list(fold, predicted, clase_ternaria)]

  res <- list()
  res$public  <- tbl[fold==1 & predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 1072500, -27500))]/0.3
  res$private <- tbl[fold==2 & predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 1072500, -27500))]/0.7
  res$total <- tbl[predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 1072500, -27500))]

  prealidad[, predicted:=NULL]
  return( res )
}

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset
dataset <- fread("/content/datasets/competencia_01.csv.gz", stringsAsFactors= TRUE)

# %%
dataset_train <- dataset[foto_mes %in% PARAM$train]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0
#  a partir de ahora ya NO puedo cortar  por prob(BAJA+2) > 1/40

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in%  PARAM$train &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 18252
# [1] 154

# %% [markdown]
# ### 2.2.5 Configuracion Bayesian Optimization

# %% [markdown]
# Cambio y ajuste en esta función. Capturo el num_iterations de mejor score.

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  AUC <- modelocv$best_score

  # cantidad de arboles que el early stopping encontro optima
  iteracion_optima <- modelocv$best_iter        # <-- AGREGAR

  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"),
          " AUC ", AUC, "  iter ", iteracion_optima)

  # mlrMBO guarda esto como columna extra en el opt.path
  attr(AUC, "extras") <- list(num_iterations= iteracion_optima)   # <-- AGREGAR

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# ### 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Mon Sep 07 07:34:07 PM 2026 AUC 0.915577398450695  iter 430
#
# Mon Sep 07 07:34:43 PM 2026 AUC 0.917323173314607  iter 537
#
# Mon Sep 07 07:35:03 PM 2026 AUC 0.915597050121018  iter 305
#
# Mon Sep 07 07:35:25 PM 2026 AUC 0.919432034708835  iter 271
#
# Mon Sep 07 07:35:46 PM 2026 AUC 0.918758613061511  iter 233
#
# Mon Sep 07 07:36:03 PM 2026 AUC 0.921151765254875  iter 171
#
# Mon Sep 07 07:36:15 PM 2026 AUC 0.917114475798018  iter 209
#
# Mon Sep 07 07:36:48 PM 2026 AUC 0.919948951875858  iter 426
#
# Mon Sep 07 07:37:06 PM 2026 AUC 0.921988449790888  iter 114
#
# Mon Sep 07 07:38:15 PM 2026 AUC 0.921152638507075  iter 1044
#
# Mon Sep 07 07:38:57 PM 2026 AUC 0.9119803858433  iter 812
#
# Mon Sep 07 07:39:30 PM 2026 AUC 0.905434771220146  iter 507
#
# Mon Sep 07 07:40:04 PM 2026 AUC 0.924167015135592  iter 547
#
# Mon Sep 07 07:40:35 PM 2026 AUC 0.923504332293945  iter 380
#
# Mon Sep 07 07:40:56 PM 2026 AUC 0.912164514678451  iter 229
#
# Mon Sep 07 07:41:01 PM 2026 AUC 0.921744902911032  iter 97
#
# Mon Sep 07 07:41:09 PM 2026 AUC 0.904293197822811  iter 70
#
# Mon Sep 07 07:42:42 PM 2026 AUC 0.913034840914664  iter 1789
#
# Mon Sep 07 07:42:58 PM 2026 AUC 0.918110379491921  iter 201
#
# Mon Sep 07 07:43:15 PM 2026 AUC 0.917108225317435  iter 166
#
# Mon Sep 07 07:43:30 PM 2026 AUC 0.921501738457037  iter 119
#
# Mon Sep 07 07:43:51 PM 2026 AUC 0.923485687580275  iter 228
#
# Mon Sep 07 07:44:14 PM 2026 AUC 0.907209887864551  iter 925
#
# Mon Sep 07 07:44:28 PM 2026 AUC 0.911856510702604  iter 121
#
# Mon Sep 07 07:44:53 PM 2026 AUC 0.916598165934773  iter 293
#
# Mon Sep 07 07:46:22 PM 2026 AUC 0.911298908786069  iter 2044
#
# Mon Sep 07 07:46:38 PM 2026 AUC 0.924596243216006  iter 81
#
# Mon Sep 07 07:46:57 PM 2026 AUC 0.918320855177811  iter 221
#
# [mbo] 0: learning_rate=0.0589; feature_fraction=0.579; num_leaves=741; min_data_in_leaf=2256; lambda_l1=0.0609; lambda_l2=0.179; min_gain_to_split=0.0675 : y = 0.916 : 31.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0383; feature_fraction=0.385; num_leaves=498; min_data_in_leaf=1837; lambda_l1=1.25; lambda_l2=2; min_gain_to_split=0.238 : y = 0.917 : 36.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0745; feature_fraction=0.609; num_leaves=658; min_data_in_leaf=2149; lambda_l1=0.0349; lambda_l2=35.3; min_gain_to_split=0.669 : y = 0.916 : 19.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0668; feature_fraction=0.408; num_leaves=453; min_data_in_leaf=1401; lambda_l1=0.0671; lambda_l2=0.0807; min_gain_to_split=0.00321 : y = 0.919 : 22.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0556; feature_fraction=0.593; num_leaves=571; min_data_in_leaf=1719; lambda_l1=3.12; lambda_l2=0.0516; min_gain_to_split=0.136 : y = 0.919 : 21.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0719; feature_fraction=0.46; num_leaves=325; min_data_in_leaf=1130; lambda_l1=0.00967; lambda_l2=10.3; min_gain_to_split=1.73 : y = 0.921 : 17.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.051; feature_fraction=0.63; num_leaves=232; min_data_in_leaf=667; lambda_l1=34.1; lambda_l2=25.6; min_gain_to_split=0.0461 : y = 0.917 : 12.1 secs : initdesign
#
# [mbo] 0: learning_rate=0.0431; feature_fraction=0.484; num_leaves=934; min_data_in_leaf=1447; lambda_l1=0.0077; lambda_l2=4.34; min_gain_to_split=0.148 : y = 0.92 : 32.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.0996; feature_fraction=0.524; num_leaves=696; min_data_in_leaf=690; lambda_l1=0.633; lambda_l2=14.6; min_gain_to_split=0.0807 : y = 0.922 : 18.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0166; feature_fraction=0.492; num_leaves=854; min_data_in_leaf=1306; lambda_l1=0; lambda_l2=0; min_gain_to_split=0.00644 : y = 0.921 : 68.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0525; feature_fraction=0.313; num_leaves=404; min_data_in_leaf=2673; lambda_l1=0.266; lambda_l2=0.424; min_gain_to_split=0.0334 : y = 0.912 : 42.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0345; feature_fraction=0.511; num_leaves=158; min_data_in_leaf=2919; lambda_l1=23.5; lambda_l2=2.76; min_gain_to_split=0.295 : y = 0.905 : 32.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0314; feature_fraction=0.418; num_leaves=78; min_data_in_leaf=327; lambda_l1=14.4; lambda_l2=0.224; min_gain_to_split=0.00198 : y = 0.924 : 34.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0231; feature_fraction=0.359; num_leaves=143; min_data_in_leaf=470; lambda_l1=0.0023; lambda_l2=0.00593; min_gain_to_split=0.0159 : y = 0.924 : 30.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0858; feature_fraction=0.355; num_leaves=675; min_data_in_leaf=2444; lambda_l1=4.59; lambda_l2=0.0211; min_gain_to_split=0.891 : y = 0.912 : 20.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0637; feature_fraction=0.647; num_leaves=627; min_data_in_leaf=63; lambda_l1=8.3; lambda_l2=0.0163; min_gain_to_split=2.41 : y = 0.922 : 5.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0704; feature_fraction=0.665; num_leaves=930; min_data_in_leaf=2337; lambda_l1=79.9; lambda_l2=0.957; min_gain_to_split=6.83 : y = 0.904 : 8.0 secs : initdesign
#
# [mbo] 0: learning_rate=0.0198; feature_fraction=0.543; num_leaves=553; min_data_in_leaf=2495; lambda_l1=0.0165; lambda_l2=96.9; min_gain_to_split=0.432 : y = 0.913 : 92.4 secs : initdesign
#
# [mbo] 0: learning_rate=0.0814; feature_fraction=0.561; num_leaves=295; min_data_in_leaf=1572; lambda_l1=0.0238; lambda_l2=0.00308; min_gain_to_split=1.04 : y = 0.918 : 16.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0403; feature_fraction=0.435; num_leaves=98; min_data_in_leaf=1005; lambda_l1=11.2; lambda_l2=0.0289; min_gain_to_split=4.42 : y = 0.917 : 16.2 secs : initdesign
#
# [mbo] 0: learning_rate=0.0802; feature_fraction=0.324; num_leaves=975; min_data_in_leaf=836; lambda_l1=0.11; lambda_l2=0.591; min_gain_to_split=0.00753 : y = 0.922 : 15.7 secs : initdesign
#
# [mbo] 0: learning_rate=0.0477; feature_fraction=0.678; num_leaves=791; min_data_in_leaf=570; lambda_l1=2.42; lambda_l2=1.42; min_gain_to_split=0.00455 : y = 0.923 : 20.3 secs : initdesign
#
# [mbo] 0: learning_rate=0.0146; feature_fraction=0.687; num_leaves=482; min_data_in_leaf=2798; lambda_l1=0.336; lambda_l2=0.00811; min_gain_to_split=2.76 : y = 0.907 : 22.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0952; feature_fraction=0.532; num_leaves=813; min_data_in_leaf=1982; lambda_l1=48; lambda_l2=0.00385; min_gain_to_split=0.0116 : y = 0.912 : 14.9 secs : initdesign
#
# [mbo] 0: learning_rate=0.0908; feature_fraction=0.399; num_leaves=271; min_data_in_leaf=1918; lambda_l1=0.165; lambda_l2=56.6; min_gain_to_split=0.0251 : y = 0.917 : 24.8 secs : initdesign
#
# [mbo] 0: learning_rate=0.012; feature_fraction=0.33; num_leaves=208; min_data_in_leaf=2767; lambda_l1=0.00184; lambda_l2=0.109; min_gain_to_split=0 : y = 0.911 : 88.5 secs : initdesign
#
# [mbo] 0: learning_rate=0.0892; feature_fraction=0.617; num_leaves=367; min_data_in_leaf=247; lambda_l1=0.00495; lambda_l2=0.00193; min_gain_to_split=0.0014 : y = 0.925 : 16.6 secs : initdesign
#
# [mbo] 0: learning_rate=0.0275; feature_fraction=0.449; num_leaves=892; min_data_in_leaf=971; lambda_l1=0.986; lambda_l2=7.28; min_gain_to_split=7.43 : y = 0.918 : 19.1 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Mon Sep 07 07:47:30 PM 2026 AUC 0.924981943888982  iter 149
#
# [mbo] 1: learning_rate=0.043; feature_fraction=0.49; num_leaves=347; min_data_in_leaf=66; lambda_l1=1.97; lambda_l2=0.0207; min_gain_to_split=0.00131 : y = 0.925 : 31.0 secs : infill_ei
#
# Mon Sep 07 07:47:50 PM 2026 AUC 0.92505420233966  iter 85
#
# [mbo] 2: learning_rate=0.0611; feature_fraction=0.581; num_leaves=633; min_data_in_leaf=264; lambda_l1=0.00378; lambda_l2=0.149; min_gain_to_split=0.0401 : y = 0.925 : 19.4 secs : infill_ei
#
# Mon Sep 07 07:48:23 PM 2026 AUC 0.925632990098583  iter 340
#
# [mbo] 3: learning_rate=0.0245; feature_fraction=0.383; num_leaves=631; min_data_in_leaf=249; lambda_l1=4.15; lambda_l2=0.0347; min_gain_to_split=0.0014 : y = 0.926 : 32.1 secs : infill_ei
#
# Mon Sep 07 07:48:53 PM 2026 AUC 0.925549927165791  iter 253
#
# [mbo] 4: learning_rate=0.0289; feature_fraction=0.548; num_leaves=625; min_data_in_leaf=344; lambda_l1=3.28; lambda_l2=0; min_gain_to_split=0 : y = 0.926 : 29.6 secs : infill_ei
#
# Mon Sep 07 07:49:21 PM 2026 AUC 0.924906872388667  iter 249
#
# [mbo] 5: learning_rate=0.0239; feature_fraction=0.61; num_leaves=679; min_data_in_leaf=300; lambda_l1=0.0134; lambda_l2=0.00299; min_gain_to_split=0.00284 : y = 0.925 : 27.5 secs : infill_ei
#
# Mon Sep 07 07:49:44 PM 2026 AUC 0.925123738418391  iter 134
#
# [mbo] 6: learning_rate=0.0592; feature_fraction=0.454; num_leaves=661; min_data_in_leaf=310; lambda_l1=3.12; lambda_l2=0.0125; min_gain_to_split=0 : y = 0.925 : 21.8 secs : infill_ei
#
# Mon Sep 07 07:50:04 PM 2026 AUC 0.922686108304252  iter 170
#
# [mbo] 7: learning_rate=0.0431; feature_fraction=0.601; num_leaves=348; min_data_in_leaf=410; lambda_l1=0.00449; lambda_l2=2.01; min_gain_to_split=0.00134 : y = 0.923 : 19.4 secs : infill_ei
#
# Mon Sep 07 07:50:28 PM 2026 AUC 0.925016513243376  iter 83
#
# [mbo] 8: learning_rate=0.0748; feature_fraction=0.48; num_leaves=671; min_data_in_leaf=141; lambda_l1=0.00667; lambda_l2=0; min_gain_to_split=0.0746 : y = 0.925 : 22.7 secs : infill_ei
#
# Mon Sep 07 07:50:45 PM 2026 AUC 0.924728910300614  iter 102
#
# [mbo] 9: learning_rate=0.0601; feature_fraction=0.692; num_leaves=651; min_data_in_leaf=338; lambda_l1=0.00225; lambda_l2=0; min_gain_to_split=0.0471 : y = 0.925 : 16.2 secs : infill_ei
#
# Mon Sep 07 07:51:31 PM 2026 AUC 0.925762684616405  iter 445
#
# [mbo] 10: learning_rate=0.0194; feature_fraction=0.511; num_leaves=637; min_data_in_leaf=231; lambda_l1=2.7; lambda_l2=0.0119; min_gain_to_split=0.00872 : y = 0.926 : 45.6 secs : infill_ei
#
# Mon Sep 07 07:52:06 PM 2026 AUC 0.924923508560898  iter 396
#
# [mbo] 11: learning_rate=0.0235; feature_fraction=0.364; num_leaves=495; min_data_in_leaf=238; lambda_l1=3.31; lambda_l2=0.00208; min_gain_to_split=0.00761 : y = 0.925 : 34.4 secs : infill_ei
#
# Mon Sep 07 07:52:56 PM 2026 AUC 0.925615603646773  iter 390
#
# [mbo] 12: learning_rate=0.0176; feature_fraction=0.574; num_leaves=664; min_data_in_leaf=51; lambda_l1=4.21; lambda_l2=0.0181; min_gain_to_split=0 : y = 0.926 : 49.0 secs : infill_ei
#
# Mon Sep 07 07:53:20 PM 2026 AUC 0.925405426233375  iter 172
#
# [mbo] 13: learning_rate=0.0365; feature_fraction=0.59; num_leaves=787; min_data_in_leaf=215; lambda_l1=1.03; lambda_l2=0.00608; min_gain_to_split=0.00464 : y = 0.925 : 23.5 secs : infill_ei
#
# Mon Sep 07 07:53:41 PM 2026 AUC 0.923569560410005  iter 69
#
# [mbo] 14: learning_rate=0.0976; feature_fraction=0.529; num_leaves=712; min_data_in_leaf=373; lambda_l1=0; lambda_l2=0.0113; min_gain_to_split=0.024 : y = 0.924 : 20.1 secs : infill_ei
#
# Mon Sep 07 07:54:03 PM 2026 AUC 0.921901591262653  iter 95
#
# [mbo] 15: learning_rate=0.0794; feature_fraction=0.655; num_leaves=561; min_data_in_leaf=56; lambda_l1=0.0183; lambda_l2=0.0131; min_gain_to_split=0.0578 : y = 0.922 : 20.7 secs : infill_ei
#
# Mon Sep 07 07:54:31 PM 2026 AUC 0.925269523684133  iter 152
#
# [mbo] 16: learning_rate=0.0512; feature_fraction=0.51; num_leaves=732; min_data_in_leaf=296; lambda_l1=0.00425; lambda_l2=0; min_gain_to_split=0.00613 : y = 0.925 : 26.7 secs : infill_ei
#
# Mon Sep 07 07:55:03 PM 2026 AUC 0.925871051878158  iter 260
#
# [mbo] 17: learning_rate=0.0247; feature_fraction=0.537; num_leaves=594; min_data_in_leaf=272; lambda_l1=0.00379; lambda_l2=0.00154; min_gain_to_split=0.486 : y = 0.926 : 31.4 secs : infill_ei
#
# Mon Sep 07 07:56:05 PM 2026 AUC 0.926014695333235  iter 730
#
# [mbo] 18: learning_rate=0.0101; feature_fraction=0.562; num_leaves=634; min_data_in_leaf=273; lambda_l1=1.51; lambda_l2=0.0392; min_gain_to_split=0 : y = 0.926 : 61.3 secs : infill_ei
#
# Mon Sep 07 07:56:29 PM 2026 AUC 0.925229298310808  iter 137
#
# [mbo] 19: learning_rate=0.051; feature_fraction=0.422; num_leaves=655; min_data_in_leaf=394; lambda_l1=0; lambda_l2=0; min_gain_to_split=0.298 : y = 0.925 : 23.4 secs : infill_ei
#
# Mon Sep 07 07:56:45 PM 2026 AUC 0.924832466576798  iter 87
#
# [mbo] 20: learning_rate=0.0662; feature_fraction=0.482; num_leaves=321; min_data_in_leaf=282; lambda_l1=0.00237; lambda_l2=0; min_gain_to_split=0.994 : y = 0.925 : 15.7 secs : infill_ei
#
# Mon Sep 07 07:57:35 PM 2026 AUC 0.925330562040303  iter 563
#
# [mbo] 21: learning_rate=0.0119; feature_fraction=0.375; num_leaves=703; min_data_in_leaf=258; lambda_l1=0.00417; lambda_l2=0.00265; min_gain_to_split=0.213 : y = 0.925 : 49.5 secs : infill_ei
#
# Saved the current state after iteration 22 in the file bayesiana.RDATA.
#
# Mon Sep 07 07:58:04 PM 2026 AUC 0.924094794049496  iter 210
#
# [mbo] 22: learning_rate=0.0372; feature_fraction=0.541; num_leaves=679; min_data_in_leaf=542; lambda_l1=0.00456; lambda_l2=0.00195; min_gain_to_split=0.398 : y = 0.924 : 27.7 secs : infill_ei
#
# Mon Sep 07 07:58:39 PM 2026 AUC 0.924263283575251  iter 241
#
# [mbo] 23: learning_rate=0.0216; feature_fraction=0.538; num_leaves=779; min_data_in_leaf=183; lambda_l1=0; lambda_l2=0; min_gain_to_split=0.134 : y = 0.924 : 34.0 secs : infill_ei
#
# Mon Sep 07 07:59:15 PM 2026 AUC 0.924458198143348  iter 323
#
# [mbo] 24: learning_rate=0.0232; feature_fraction=0.567; num_leaves=756; min_data_in_leaf=214; lambda_l1=3.61; lambda_l2=0.241; min_gain_to_split=0.00129 : y = 0.924 : 35.1 secs : infill_ei
#
# Mon Sep 07 07:59:48 PM 2026 AUC 0.926668163780492  iter 260
#
# [mbo] 25: learning_rate=0.0282; feature_fraction=0.444; num_leaves=554; min_data_in_leaf=222; lambda_l1=0.00322; lambda_l2=0; min_gain_to_split=0.019 : y = 0.927 : 32.0 secs : infill_ei
#
# Mon Sep 07 08:00:12 PM 2026 AUC 0.924213500032629  iter 101
#
# [mbo] 26: learning_rate=0.0567; feature_fraction=0.371; num_leaves=553; min_data_in_leaf=171; lambda_l1=0.00257; lambda_l2=0; min_gain_to_split=0 : y = 0.924 : 23.6 secs : infill_ei
#
# Mon Sep 07 08:01:02 PM 2026 AUC 0.925984786016362  iter 798
#
# [mbo] 27: learning_rate=0.01; feature_fraction=0.682; num_leaves=156; min_data_in_leaf=191; lambda_l1=4.48; lambda_l2=0.0174; min_gain_to_split=0.00133 : y = 0.926 : 48.9 secs : infill_ei
#
# Mon Sep 07 08:01:59 PM 2026 AUC 0.925862462168845  iter 520
#
# [mbo] 28: learning_rate=0.0102; feature_fraction=0.507; num_leaves=510; min_data_in_leaf=236; lambda_l1=0.00393; lambda_l2=0; min_gain_to_split=0.023 : y = 0.926 : 56.9 secs : infill_ei
#
# Mon Sep 07 08:02:27 PM 2026 AUC 0.925462434459915  iter 250
#
# [mbo] 29: learning_rate=0.0261; feature_fraction=0.402; num_leaves=570; min_data_in_leaf=51; lambda_l1=0.00226; lambda_l2=0.589; min_gain_to_split=1.42 : y = 0.925 : 27.3 secs : infill_ei
#
# Mon Sep 07 08:02:52 PM 2026 AUC 0.925048943667048  iter 242
#
# [mbo] 30: learning_rate=0.0247; feature_fraction=0.699; num_leaves=579; min_data_in_leaf=262; lambda_l1=1.23; lambda_l2=0.00247; min_gain_to_split=0.00194 : y = 0.925 : 24.4 secs : infill_ei
#
# Mon Sep 07 08:04:02 PM 2026 AUC 0.925157292321222  iter 796
#
# [mbo] 31: learning_rate=0.0101; feature_fraction=0.474; num_leaves=62; min_data_in_leaf=109; lambda_l1=6.13; lambda_l2=0.00753; min_gain_to_split=0 : y = 0.925 : 68.5 secs : infill_ei
#
# Mon Sep 07 08:04:50 PM 2026 AUC 0.925267277038866  iter 483
#
# [mbo] 32: learning_rate=0.0138; feature_fraction=0.438; num_leaves=633; min_data_in_leaf=290; lambda_l1=0.341; lambda_l2=0.0117; min_gain_to_split=0.00341 : y = 0.925 : 47.4 secs : infill_ei
#
# Mon Sep 07 08:05:17 PM 2026 AUC 0.926245432424295  iter 164
#
# [mbo] 33: learning_rate=0.0333; feature_fraction=0.423; num_leaves=540; min_data_in_leaf=230; lambda_l1=0.0033; lambda_l2=0.0762; min_gain_to_split=0.162 : y = 0.926 : 25.2 secs : infill_ei
#
# Mon Sep 07 08:06:32 PM 2026 AUC 0.925398522684883  iter 968
#
# [mbo] 34: learning_rate=0.0107; feature_fraction=0.576; num_leaves=325; min_data_in_leaf=281; lambda_l1=7.94; lambda_l2=0.0169; min_gain_to_split=0 : y = 0.925 : 74.2 secs : infill_ei
#
# Mon Sep 07 08:06:48 PM 2026 AUC 0.923741526962688  iter 81
#
# [mbo] 35: learning_rate=0.0987; feature_fraction=0.661; num_leaves=50; min_data_in_leaf=378; lambda_l1=4.63; lambda_l2=0.0208; min_gain_to_split=0 : y = 0.924 : 15.1 secs : infill_ei
#
# Mon Sep 07 08:07:21 PM 2026 AUC 0.925720237751294  iter 175
#
# [mbo] 36: learning_rate=0.0309; feature_fraction=0.438; num_leaves=576; min_data_in_leaf=190; lambda_l1=0.00312; lambda_l2=0.00129; min_gain_to_split=0.0615 : y = 0.926 : 31.6 secs : infill_ei
#
# Mon Sep 07 08:07:41 PM 2026 AUC 0.925213733313333  iter 116
#
# [mbo] 37: learning_rate=0.0656; feature_fraction=0.368; num_leaves=620; min_data_in_leaf=237; lambda_l1=0.00348; lambda_l2=0.0361; min_gain_to_split=0.627 : y = 0.925 : 18.9 secs : infill_ei
#
# Saved the current state after iteration 38 in the file bayesiana.RDATA.
#
# Mon Sep 07 08:08:21 PM 2026 AUC 0.92566426089535  iter 381
#
# [mbo] 38: learning_rate=0.0192; feature_fraction=0.443; num_leaves=569; min_data_in_leaf=295; lambda_l1=0.00191; lambda_l2=5.95; min_gain_to_split=0.555 : y = 0.926 : 39.5 secs : infill_ei
#
# Mon Sep 07 08:09:02 PM 2026 AUC 0.925512343352628  iter 258
#
# [mbo] 39: learning_rate=0.0239; feature_fraction=0.42; num_leaves=565; min_data_in_leaf=218; lambda_l1=0.006; lambda_l2=0.0551; min_gain_to_split=0.016 : y = 0.926 : 39.6 secs : infill_ei
#
# Mon Sep 07 08:09:35 PM 2026 AUC 0.925251242138506  iter 153
#
# [mbo] 40: learning_rate=0.0358; feature_fraction=0.456; num_leaves=521; min_data_in_leaf=60; lambda_l1=0.00234; lambda_l2=0.00616; min_gain_to_split=0.302 : y = 0.925 : 31.3 secs : infill_ei
#
# Mon Sep 07 08:10:06 PM 2026 AUC 0.926206345924786  iter 226
#
# [mbo] 41: learning_rate=0.0278; feature_fraction=0.471; num_leaves=521; min_data_in_leaf=276; lambda_l1=0.00369; lambda_l2=0.28; min_gain_to_split=0.477 : y = 0.926 : 30.4 secs : infill_ei
#
# Mon Sep 07 08:10:37 PM 2026 AUC 0.924381496166099  iter 260
#
# [mbo] 42: learning_rate=0.0334; feature_fraction=0.4; num_leaves=930; min_data_in_leaf=295; lambda_l1=1.15; lambda_l2=0.0398; min_gain_to_split=0.209 : y = 0.924 : 30.0 secs : infill_ei
#
# Mon Sep 07 08:10:56 PM 2026 AUC 0.921186820030853  iter 116
#
# [mbo] 43: learning_rate=0.0429; feature_fraction=0.496; num_leaves=553; min_data_in_leaf=265; lambda_l1=0.00148; lambda_l2=0.383; min_gain_to_split=9.93 : y = 0.921 : 17.9 secs : infill_ei
#
# Mon Sep 07 08:11:21 PM 2026 AUC 0.926140323871002  iter 156
#
# [mbo] 44: learning_rate=0.0433; feature_fraction=0.401; num_leaves=380; min_data_in_leaf=215; lambda_l1=0.00332; lambda_l2=1.48; min_gain_to_split=0.264 : y = 0.926 : 22.7 secs : infill_ei
#
# Mon Sep 07 08:11:51 PM 2026 AUC 0.925111320775992  iter 291
#
# [mbo] 45: learning_rate=0.0255; feature_fraction=0.312; num_leaves=577; min_data_in_leaf=247; lambda_l1=0.00296; lambda_l2=0.871; min_gain_to_split=0.267 : y = 0.925 : 29.8 secs : infill_ei
#
# Mon Sep 07 08:13:02 PM 2026 AUC 0.923516868512116  iter 956
#
# [mbo] 46: learning_rate=0.0103; feature_fraction=0.443; num_leaves=725; min_data_in_leaf=638; lambda_l1=2.07; lambda_l2=0.0119; min_gain_to_split=0.00188 : y = 0.924 : 69.8 secs : infill_ei
#
# Mon Sep 07 08:13:29 PM 2026 AUC 0.925093711505406  iter 129
#
# [mbo] 47: learning_rate=0.0646; feature_fraction=0.428; num_leaves=535; min_data_in_leaf=296; lambda_l1=0.00325; lambda_l2=0; min_gain_to_split=0.0195 : y = 0.925 : 26.0 secs : infill_ei
#
# Mon Sep 07 08:13:53 PM 2026 AUC 0.92526751158316  iter 166
#
# [mbo] 48: learning_rate=0.0304; feature_fraction=0.618; num_leaves=59; min_data_in_leaf=199; lambda_l1=0.00229; lambda_l2=0; min_gain_to_split=0.00818 : y = 0.925 : 23.1 secs : infill_ei
#
# Mon Sep 07 08:14:38 PM 2026 AUC 0.926801735423174  iter 471
#
# [mbo] 49: learning_rate=0.0148; feature_fraction=0.414; num_leaves=440; min_data_in_leaf=217; lambda_l1=0.0593; lambda_l2=0; min_gain_to_split=0.828 : y = 0.927 : 44.1 secs : infill_ei
#
# Mon Sep 07 08:15:06 PM 2026 AUC 0.925249328621266  iter 215
#
# [mbo] 50: learning_rate=0.0284; feature_fraction=0.419; num_leaves=395; min_data_in_leaf=228; lambda_l1=0.0712; lambda_l2=0.699; min_gain_to_split=1.05 : y = 0.925 : 27.3 secs : infill_ei
#
# Mon Sep 07 08:15:25 PM 2026 AUC 0.925062591460199  iter 88
#
# [mbo] 51: learning_rate=0.0909; feature_fraction=0.444; num_leaves=656; min_data_in_leaf=218; lambda_l1=0.00137; lambda_l2=4.37; min_gain_to_split=0.448 : y = 0.925 : 17.4 secs : infill_ei
#
# Mon Sep 07 08:16:00 PM 2026 AUC 0.924956381466399  iter 237
#
# [mbo] 52: learning_rate=0.0262; feature_fraction=0.453; num_leaves=541; min_data_in_leaf=50; lambda_l1=0.685; lambda_l2=0.0806; min_gain_to_split=0.47 : y = 0.925 : 34.2 secs : infill_ei
#
# Mon Sep 07 08:17:01 PM 2026 AUC 0.926189697968498  iter 681
#
# [mbo] 53: learning_rate=0.0105; feature_fraction=0.42; num_leaves=118; min_data_in_leaf=202; lambda_l1=0.00193; lambda_l2=0.0517; min_gain_to_split=0.615 : y = 0.926 : 59.4 secs : infill_ei
#
# Mon Sep 07 08:17:24 PM 2026 AUC 0.925004695535547  iter 205
#
# [mbo] 54: learning_rate=0.0317; feature_fraction=0.41; num_leaves=542; min_data_in_leaf=185; lambda_l1=0.143; lambda_l2=0; min_gain_to_split=0.73 : y = 0.925 : 22.3 secs : infill_ei
#
# Mon Sep 07 08:18:21 PM 2026 AUC 0.927077427655655  iter 702
#
# [mbo] 55: learning_rate=0.0101; feature_fraction=0.478; num_leaves=376; min_data_in_leaf=224; lambda_l1=0.00211; lambda_l2=0.0304; min_gain_to_split=1.18 : y = 0.927 : 55.5 secs : infill_ei
#
# Saved the current state after iteration 56 in the file bayesiana.RDATA.
#
# Mon Sep 07 08:19:03 PM 2026 AUC 0.925667472712809  iter 575
#
# [mbo] 56: learning_rate=0.01; feature_fraction=0.62; num_leaves=374; min_data_in_leaf=202; lambda_l1=0.0115; lambda_l2=0.00136; min_gain_to_split=0.958 : y = 0.926 : 40.9 secs : infill_ei
#
# Mon Sep 07 08:19:22 PM 2026 AUC 0.925086086125935  iter 107
#
# [mbo] 57: learning_rate=0.0694; feature_fraction=0.452; num_leaves=333; min_data_in_leaf=302; lambda_l1=0; lambda_l2=0.204; min_gain_to_split=0.181 : y = 0.925 : 18.4 secs : infill_ei
#
# Mon Sep 07 08:20:14 PM 2026 AUC 0.925526409399759  iter 654
#
# [mbo] 58: learning_rate=0.0101; feature_fraction=0.401; num_leaves=505; min_data_in_leaf=229; lambda_l1=0.00812; lambda_l2=0.0209; min_gain_to_split=1.27 : y = 0.926 : 50.7 secs : infill_ei
#
# Mon Sep 07 08:20:36 PM 2026 AUC 0.925861001834456  iter 143
#
# [mbo] 59: learning_rate=0.0418; feature_fraction=0.438; num_leaves=814; min_data_in_leaf=254; lambda_l1=0.932; lambda_l2=0; min_gain_to_split=0.0214 : y = 0.926 : 20.9 secs : infill_ei
#
# Mon Sep 07 08:21:29 PM 2026 AUC 0.926354580633576  iter 579
#
# [mbo] 60: learning_rate=0.0118; feature_fraction=0.405; num_leaves=376; min_data_in_leaf=222; lambda_l1=0.00507; lambda_l2=0.0394; min_gain_to_split=0.455 : y = 0.926 : 52.7 secs : infill_ei
#
# Mon Sep 07 08:22:25 PM 2026 AUC 0.927107410509689  iter 685
#
# [mbo] 61: learning_rate=0.0104; feature_fraction=0.466; num_leaves=238; min_data_in_leaf=229; lambda_l1=0.0462; lambda_l2=0; min_gain_to_split=0.982 : y = 0.927 : 54.7 secs : infill_ei
#
# Mon Sep 07 08:23:01 PM 2026 AUC 0.925526702517621  iter 544
#
# [mbo] 62: learning_rate=0.0111; feature_fraction=0.61; num_leaves=219; min_data_in_leaf=215; lambda_l1=0.928; lambda_l2=0; min_gain_to_split=0.822 : y = 0.926 : 35.7 secs : infill_ei
#
# Mon Sep 07 08:23:38 PM 2026 AUC 0.925864748443856  iter 368
#
# [mbo] 63: learning_rate=0.0637; feature_fraction=0.401; num_leaves=829; min_data_in_leaf=210; lambda_l1=0.00139; lambda_l2=99.3; min_gain_to_split=0.188 : y = 0.926 : 35.9 secs : infill_ei
#
# Mon Sep 07 08:24:31 PM 2026 AUC 0.926706011861333  iter 622
#
# [mbo] 64: learning_rate=0.0133; feature_fraction=0.473; num_leaves=389; min_data_in_leaf=274; lambda_l1=0.665; lambda_l2=0.0016; min_gain_to_split=0.215 : y = 0.927 : 51.9 secs : infill_ei
#
# Mon Sep 07 08:24:56 PM 2026 AUC 0.926124413821122  iter 145
#
# [mbo] 65: learning_rate=0.0528; feature_fraction=0.468; num_leaves=675; min_data_in_leaf=228; lambda_l1=0.00303; lambda_l2=8.66; min_gain_to_split=0.252 : y = 0.926 : 23.8 secs : infill_ei
#
# Mon Sep 07 08:25:35 PM 2026 AUC 0.925326142791935  iter 376
#
# [mbo] 66: learning_rate=0.0155; feature_fraction=0.461; num_leaves=330; min_data_in_leaf=246; lambda_l1=0.00146; lambda_l2=0; min_gain_to_split=0.848 : y = 0.925 : 38.2 secs : infill_ei
#
# Mon Sep 07 08:26:30 PM 2026 AUC 0.925689739263214  iter 584
#
# [mbo] 67: learning_rate=0.01; feature_fraction=0.522; num_leaves=384; min_data_in_leaf=211; lambda_l1=0.0854; lambda_l2=0.00171; min_gain_to_split=0.292 : y = 0.926 : 53.8 secs : infill_ei
#
# Mon Sep 07 08:27:26 PM 2026 AUC 0.925288420562279  iter 622
#
# [mbo] 68: learning_rate=0.0102; feature_fraction=0.487; num_leaves=587; min_data_in_leaf=200; lambda_l1=1.84; lambda_l2=0.00177; min_gain_to_split=0.16 : y = 0.925 : 55.0 secs : infill_ei
#
# Mon Sep 07 08:28:18 PM 2026 AUC 0.925887270024536  iter 674
#
# [mbo] 69: learning_rate=0.0101; feature_fraction=0.564; num_leaves=204; min_data_in_leaf=200; lambda_l1=0.0031; lambda_l2=0.22; min_gain_to_split=1.28 : y = 0.926 : 51.1 secs : infill_ei
#
# Mon Sep 07 08:28:52 PM 2026 AUC 0.926073315623176  iter 357
#
# [mbo] 70: learning_rate=0.0161; feature_fraction=0.599; num_leaves=56; min_data_in_leaf=219; lambda_l1=0.841; lambda_l2=0.0796; min_gain_to_split=0.0089 : y = 0.926 : 33.0 secs : infill_ei
#
# Saved the current state after iteration 71 in the file bayesiana.RDATA.
#
# Mon Sep 07 08:29:48 PM 2026 AUC 0.926525081029008  iter 646
#
# [mbo] 71: learning_rate=0.0116; feature_fraction=0.417; num_leaves=70; min_data_in_leaf=269; lambda_l1=0.738; lambda_l2=0.204; min_gain_to_split=0.206 : y = 0.927 : 54.2 secs : infill_ei
#
# Mon Sep 07 08:30:26 PM 2026 AUC 0.925377240721811  iter 423
#
# [mbo] 72: learning_rate=0.0162; feature_fraction=0.46; num_leaves=91; min_data_in_leaf=374; lambda_l1=0.865; lambda_l2=0.03; min_gain_to_split=0.0306 : y = 0.925 : 37.1 secs : infill_ei
#
# Mon Sep 07 08:30:56 PM 2026 AUC 0.926123341340658  iter 304
#
# [mbo] 73: learning_rate=0.0219; feature_fraction=0.699; num_leaves=434; min_data_in_leaf=200; lambda_l1=0.00196; lambda_l2=0.0416; min_gain_to_split=0.00544 : y = 0.926 : 29.2 secs : infill_ei
#
# Mon Sep 07 08:31:14 PM 2026 AUC 0.925971923601668  iter 72
#
# [mbo] 74: learning_rate=0.085; feature_fraction=0.461; num_leaves=792; min_data_in_leaf=276; lambda_l1=0.95; lambda_l2=0; min_gain_to_split=0.2 : y = 0.926 : 16.0 secs : infill_ei
#
# Mon Sep 07 08:31:45 PM 2026 AUC 0.925639205443252  iter 304
#
# [mbo] 75: learning_rate=0.0217; feature_fraction=0.453; num_leaves=388; min_data_in_leaf=211; lambda_l1=0.00245; lambda_l2=0.0923; min_gain_to_split=0.796 : y = 0.926 : 29.8 secs : infill_ei
#
# Mon Sep 07 08:32:16 PM 2026 AUC 0.926485179975349  iter 209
#
# [mbo] 76: learning_rate=0.0276; feature_fraction=0.503; num_leaves=677; min_data_in_leaf=213; lambda_l1=0.00223; lambda_l2=0; min_gain_to_split=0.00274 : y = 0.926 : 30.2 secs : infill_ei
#
# Mon Sep 07 08:32:35 PM 2026 AUC 0.924851948783325  iter 121
#
# [mbo] 77: learning_rate=0.0607; feature_fraction=0.421; num_leaves=478; min_data_in_leaf=258; lambda_l1=0.791; lambda_l2=0.00144; min_gain_to_split=0.26 : y = 0.925 : 17.7 secs : infill_ei
#
# Mon Sep 07 08:33:30 PM 2026 AUC 0.926051902770412  iter 798
#
# [mbo] 78: learning_rate=0.01; feature_fraction=0.379; num_leaves=189; min_data_in_leaf=131; lambda_l1=0.4; lambda_l2=0.00352; min_gain_to_split=1.03 : y = 0.926 : 53.6 secs : infill_ei
#
# Mon Sep 07 08:34:41 PM 2026 AUC 0.92643567449208  iter 604
#
# [mbo] 79: learning_rate=0.01; feature_fraction=0.53; num_leaves=180; min_data_in_leaf=58; lambda_l1=0.583; lambda_l2=1.43; min_gain_to_split=0.265 : y = 0.926 : 69.9 secs : infill_ei
#
# Mon Sep 07 08:34:59 PM 2026 AUC 0.924575836520784  iter 70
#
# [mbo] 80: learning_rate=0.0905; feature_fraction=0.454; num_leaves=993; min_data_in_leaf=319; lambda_l1=1.09; lambda_l2=0; min_gain_to_split=0.00408 : y = 0.925 : 17.1 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "learning_rate"     "feature_fraction"  "num_leaves"
#  [4] "min_data_in_leaf"  "lambda_l1"         "lambda_l2"
#  [7] "min_gain_to_split" "y"                 "dob"
# [10] "eol"               "error.message"     "exec.time"
# [13] "ei"                "error.model"       "train.time"
# [16] "prop.type"         "propose.time"      "se"
# [19] "mean"              "num_iterations"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    learning_rate feature_fraction num_leaves min_data_in_leaf lambda_l1
#            <num>            <num>      <int>            <int>     <num>
# 1:    0.01036975        0.4656955        238              229 -1.335709
#    lambda_l2 min_gain_to_split num_iterations
#        <num>             <num>          <int>
# 1: -2.996427      -0.007955436            685
# [1] 0.9271074

# %%
tb_bayesiana
# Out:
#     learning_rate feature_fraction num_leaves min_data_in_leaf lambda_l1
# 1   0.01036975    0.4656955        238        229              -1.33570857
# 2   0.01011420    0.4784930        376        224              -2.67569871
# 3   0.01482740    0.4140994        440        217              -1.22660730
# 4   0.01332873    0.4729214        389        274              -0.17746348
# 5   0.02815088    0.4440981        554        222              -2.49268186
# 6   0.01159797    0.4168869         70        269              -0.13171059
# 7   0.02762044    0.5029036        677        213              -2.65255547
# 8   0.01004780    0.5303287        180         58              -0.23408639
# 9   0.01183255    0.4045790        376        222              -2.29516982
# 10  0.03332592    0.4229605        540        230              -2.48203512
# 11  0.02780782    0.4707454        521        276              -2.43253428
# 12  0.01050550    0.4200539        118        202              -2.71372721
# 13  0.04334777    0.4010933        380        215              -2.47895999
# 14  0.05280695    0.4681886        675        228              -2.51867837
# 15  0.02190594    0.6988270        434        200              -2.70849655
# 16  0.01606358    0.5988918         56        219              -0.07516479
# 17  0.01002882    0.3790988        189        131              -0.39811723
# 18  0.01005914    0.5618366        634        273               0.17972917
# 19  0.01003235    0.6824042        156        191               0.65105222
# 20  0.08501622    0.4607910        792        276              -0.02217731
# 21  0.01005947    0.5642949        204        200              -2.50928772
# 22  0.02472629    0.5370383        594        272              -2.42179077
# 23  0.06369449    0.4009552        829        210              -2.85590811
# 24  0.01015779    0.5074432        510        236              -2.40599890
# 25  0.04175820    0.4376286        814        254              -0.03068517
# 26  0.01935604    0.5109160        637        231               0.43188699
# 27  0.03089124    0.4377666        576        190              -2.50555870
# 28  0.01002262    0.5216908        384        211              -1.06875687
# 29  0.01004425    0.6197783        374        202              -1.93770871
# 30  0.01923277    0.4426220        569        295              -2.71832691
# ⋮   ⋮             ⋮                ⋮          ⋮                ⋮
# 79  0.01025524    0.4426383        725         638              0.315687474
# 80  0.02314951    0.3590370        143         470             -2.637945889
# 81  0.04770912    0.6781480        791         570              0.383313983
# 82  0.04310946    0.6013930        348         410             -2.347614496
# 83  0.09962441    0.5242273        696         690             -0.198411400
# 84  0.07942070    0.6547333        561          56             -1.738321115
# 85  0.06373995    0.6471851        627          63              0.919085174
# 86  0.08021825    0.3237790        975         836             -0.957399843
# 87  0.04289397    0.4955347        553         265             -2.830102885
# 88  0.01658043    0.4917253        854        1306             -2.947620794
# 89  0.07188391    0.4601113        325        1130             -2.014699392
# 90  0.04312551    0.4842537        934        1447             -2.113296020
# 91  0.06675510    0.4083111        453        1401             -1.173171946
# 92  0.05557338    0.5925836        571        1719              0.494570427
# 93  0.02752005    0.4489326        892         971             -0.006130045
# 94  0.08137854    0.5608822        295        1572             -1.623312865
# 95  0.03825471    0.3846918        498        1837              0.095330027
# 96  0.05100943    0.6299318        232         667              1.532676704
# 97  0.04025770    0.4349565         98        1005              1.049873838
# 98  0.09078592    0.3990654        271        1918             -0.783295587
# 99  0.07450202    0.6087927        658        2149             -1.456979752
# 100 0.05889137    0.5789068        741        2256             -1.215347817
# 101 0.01978621    0.5430292        553        2495             -1.782966265
# 102 0.08583160    0.3547394        675        2444              0.661522975
# 103 0.05249435    0.3134528        404        2673             -0.575760954
# 104 0.09515374    0.5321218        813        1982              1.681174163
# 105 0.01195071    0.3298875        208        2767             -2.734186141
# 106 0.01462527    0.6867054        482        2798             -0.473083027
# 107 0.03452709    0.5107951        158        2919              1.370250529
# 108 0.07035636    0.6647496        930        2337              1.902472761
#     lambda_l2  min_gain_to_split y         dob eol ⋯ exec.time ei
# 1   -2.9964272 -0.007955436      0.9271074 61  NA  ⋯ 54.745    -1.725418e-04
# 2   -1.5172613  0.072042474      0.9270774 55  NA  ⋯ 55.478    -6.153854e-04
# 3   -2.9914330 -0.081944500      0.9268017 49  NA  ⋯ 44.102    -3.791798e-04
# 4   -2.7953779 -0.666783861      0.9267060 64  NA  ⋯ 51.866    -8.720554e-05
# 5   -2.9505240 -1.721249250      0.9266682 25  NA  ⋯ 31.974    -4.990448e-04
# 6   -0.6911840 -0.685576312      0.9265251 71  NA  ⋯ 54.150    -1.127628e-04
# 7   -2.9173654 -2.562929225      0.9264852 76  NA  ⋯ 30.161    -2.646844e-04
# 8    0.1562435 -0.576376912      0.9264357 79  NA  ⋯ 69.868    -2.577123e-04
# 9   -1.4039979 -0.342454422      0.9263546 60  NA  ⋯ 52.707    -5.973268e-04
# 10  -1.1181133 -0.789824525      0.9262454 33  NA  ⋯ 25.209    -1.587626e-04
# 11  -0.5529540 -0.321455207      0.9262063 41  NA  ⋯ 30.370    -2.133326e-04
# 12  -1.2862564 -0.210998088      0.9261897 53  NA  ⋯ 59.447    -1.367758e-04
# 13   0.1708865 -0.578595227      0.9261403 44  NA  ⋯ 22.749    -1.105871e-04
# 14   0.9376863 -0.598519475      0.9261244 65  NA  ⋯ 23.767    -9.965196e-05
# 15  -1.3813821 -2.264571873      0.9261233 73  NA  ⋯ 29.216    -1.071888e-04
# 16  -1.0989304 -2.050679877      0.9260733 70  NA  ⋯ 32.968    -4.029882e-04
# 17  -2.4531787  0.014728549      0.9260519 78  NA  ⋯ 53.562    -2.462843e-04
# 18  -1.4067072 -2.982537257      0.9260147 18  NA  ⋯ 61.263    -3.189860e-04
# 19  -1.7606203 -2.876225995      0.9259848 27  NA  ⋯ 48.929    -6.989803e-05
# 20  -2.9991724 -0.699013527      0.9259719 74  NA  ⋯ 15.958    -1.413687e-04
# 21  -0.6580198  0.108120120      0.9258873 69  NA  ⋯ 51.058    -6.922584e-04
# 22  -2.8114548 -0.313581792      0.9258711 17  NA  ⋯ 31.433    -3.458720e-04
# 23   1.9969746 -0.726648545      0.9258647 63  NA  ⋯ 35.906    -1.106573e-04
# 24  -2.9928511 -1.638910031      0.9258625 28  NA  ⋯ 56.933    -2.338287e-04
# 25  -2.9959180 -1.669147529      0.9258610 59  NA  ⋯ 20.919    -9.864543e-05
# 26  -1.9245966 -2.059267878      0.9257627 10  NA  ⋯ 45.577    -3.741583e-04
# 27  -2.8901141 -1.210976160      0.9257202 36  NA  ⋯ 31.573    -1.364034e-04
# 28  -2.7669760 -0.535114333      0.9256897 67  NA  ⋯ 53.832    -6.214197e-04
# 29  -2.8671859 -0.018785162      0.9256675 56  NA  ⋯ 40.857    -1.487916e-04
# 30   0.7744567 -0.255820525      0.9256643 38  NA  ⋯ 39.452    -2.279332e-04
# ⋮   ⋮          ⋮                 ⋮         ⋮   ⋮   ⋱ ⋮         ⋮
# 79  -1.9239724 -2.72484517       0.9235169 46  NA  ⋯ 69.766    -8.198323e-05
# 80  -2.2271941 -1.79763558       0.9235043  0  NA  ⋯ 30.683               NA
# 81   0.1513748 -2.34194391       0.9234857  0  NA  ⋯ 20.294               NA
# 82   0.3040021 -2.87421841       0.9226861  7  NA  ⋯ 19.433    -2.394686e-04
# 83   1.1655769 -1.09337152       0.9219884  0  NA  ⋯ 18.260               NA
# 84  -1.8813919 -1.23844168       0.9219016 15  NA  ⋯ 20.736    -1.716183e-04
# 85  -1.7883627  0.38152791       0.9217449  0  NA  ⋯  5.531               NA
# 86  -0.2285228 -2.12341464       0.9215017  0  NA  ⋯ 15.651               NA
# 87  -0.4167686  0.99702126       0.9211868 43  NA  ⋯ 17.898    -5.787122e-05
# 88  -2.9186316 -2.19110861       0.9211526  0  NA  ⋯ 68.896               NA
# 89   1.0145702  0.23709245       0.9211518  0  NA  ⋯ 17.052               NA
# 90   0.6374572 -0.82878866       0.9199490  0  NA  ⋯ 32.817               NA
# 91  -1.0929995 -2.49321462       0.9194320  0  NA  ⋯ 22.036               NA
# 92  -1.2869592 -0.86755236       0.9187586  0  NA  ⋯ 21.039               NA
# 93   0.8619501  0.87091754       0.9183209  0  NA  ⋯ 19.112               NA
# 94  -2.5117600  0.01550242       0.9181104  0  NA  ⋯ 16.855               NA
# 95   0.2999641 -0.62351733       0.9173232  0  NA  ⋯ 36.114               NA
# 96   1.4079791 -1.33658398       0.9171145  0  NA  ⋯ 12.143               NA
# 97  -1.5395942  0.64554043       0.9171082  0  NA  ⋯ 16.178               NA
# 98   1.7529352 -1.60111315       0.9165982  0  NA  ⋯ 24.783               NA
# 99   1.5480147 -0.17441110       0.9155971  0  NA  ⋯ 19.695               NA
# 100 -0.7477879 -1.17042289       0.9155774  0  NA  ⋯ 31.526               NA
# 101  1.9862183 -0.36472430       0.9130348  0  NA  ⋯ 92.404               NA
# 102 -1.6759971 -0.05027936       0.9121645  0  NA  ⋯ 20.628               NA
# 103 -0.3725990 -1.47651769       0.9119804  0  NA  ⋯ 42.429               NA
# 104 -2.4144416 -1.93371778       0.9118565  0  NA  ⋯ 14.900               NA
# 105 -0.9613093 -2.99684734       0.9112989  0  NA  ⋯ 88.497               NA
# 106 -2.0908780  0.44065791       0.9072099  0  NA  ⋯ 22.938               NA
# 107  0.4414473 -0.53017796       0.9054348  0  NA  ⋯ 32.328               NA
# 108 -0.0188747  0.83431454       0.9042932  0  NA  ⋯  8.033               NA
#     error.model train.time prop.type  propose.time se           mean
# 1   NA          0.115      infill_ei  0.657        0.0006271192 0.9269029
# 2   NA          0.194      infill_ei  1.148        0.0006984107 0.9273255
# 3   NA          0.116      infill_ei  0.778        0.0011689840 0.9264820
# 4   NA          0.268      infill_ei  0.669        0.0007783128 0.9264539
# 5   NA          0.118      infill_ei  0.537        0.0006456618 0.9264059
# 6   NA          0.238      infill_ei  0.690        0.0012449412 0.9259176
# 7   NA          0.481      infill_ei  0.698        0.0007959486 0.9269954
# 8   NA          0.278      infill_ei  0.689        0.0013628079 0.9263870
# 9   NA          0.221      infill_ei  0.665        0.0005027275 0.9276418
# 10  NA          0.415      infill_ei  0.988        0.0005335731 0.9265495
# 11  NA          0.172      infill_ei  0.629        0.0005019367 0.9266938
# 12  NA          0.510      infill_ei  0.694        0.0013006154 0.9256640
# 13  NA          0.395      infill_ei  0.916        0.0008354316 0.9260460
# 14  NA          0.244      infill_ei  1.060        0.0005942952 0.9267487
# 15  NA          0.276      infill_ei  1.062        0.0012982832 0.9258029
# 16  NA          0.426      infill_ei  0.697        0.0012439512 0.9269082
# 17  NA          0.298      infill_ei  1.077        0.0009534177 0.9268001
# 18  NA          0.090      infill_ei  0.549        0.0007242768 0.9259293
# 19  NA          0.198      infill_ei  0.631        0.0014547846 0.9248140
# 20  NA          0.313      infill_ei  1.120        0.0016410740 0.9254952
# 21  NA          0.146      infill_ei  0.677        0.0007268273 0.9277184
# 22  NA          0.118      infill_ei  0.559        0.0011275536 0.9255368
# 23  NA          0.246      infill_ei  0.652        0.0014045211 0.9256619
# 24  NA          0.099      infill_ei  0.586        0.0005270474 0.9267137
# 25  NA          0.140      infill_ei  0.634        0.0009879957 0.9261851
# 26  NA          0.120      infill_ei  0.530        0.0007847457 0.9257484
# 27  NA          0.167      infill_ei  0.664        0.0002049960 0.9267609
# 28  NA          0.294      infill_ei  0.674        0.0007180448 0.9276313
# 29  NA          0.154      infill_ei  0.638        0.0008731500 0.9265590
# 30  NA          0.154      infill_ei  0.640        0.0012667595 0.9259589
# ⋮   ⋮           ⋮          ⋮          ⋮            ⋮            ⋮
# 79  NA          0.358      infill_ei  0.767        0.001180995  0.9253760
# 80  NA             NA      initdesign    NA                 NA         NA
# 81  NA             NA      initdesign    NA                 NA         NA
# 82  NA          0.090      infill_ei  0.852        0.001589559  0.9245703
# 83  NA             NA      initdesign    NA                 NA         NA
# 84  NA          0.366      infill_ei  1.032        0.001068098  0.9250901
# 85  NA             NA      initdesign    NA                 NA         NA
# 86  NA             NA      initdesign    NA                 NA         NA
# 87  NA          0.210      infill_ei  1.139        0.001707734  0.9242166
# 88  NA             NA      initdesign    NA                 NA         NA
# 89  NA             NA      initdesign    NA                 NA         NA
# 90  NA             NA      initdesign    NA                 NA         NA
# 91  NA             NA      initdesign    NA                 NA         NA
# 92  NA             NA      initdesign    NA                 NA         NA
# 93  NA             NA      initdesign    NA                 NA         NA
# 94  NA             NA      initdesign    NA                 NA         NA
# 95  NA             NA      initdesign    NA                 NA         NA
# 96  NA             NA      initdesign    NA                 NA         NA
# 97  NA             NA      initdesign    NA                 NA         NA
# 98  NA             NA      initdesign    NA                 NA         NA
# 99  NA             NA      initdesign    NA                 NA         NA
# 100 NA             NA      initdesign    NA                 NA         NA
# 101 NA             NA      initdesign    NA                 NA         NA
# 102 NA             NA      initdesign    NA                 NA         NA
# 103 NA             NA      initdesign    NA                 NA         NA
# 104 NA             NA      initdesign    NA                 NA         NA
# 105 NA             NA      initdesign    NA                 NA         NA
# 106 NA             NA      initdesign    NA                 NA         NA
# 107 NA             NA      initdesign    NA                 NA         NA
# 108 NA             NA      initdesign    NA                 NA         NA
#     num_iterations iter
# 1   685             89
# 2   702             83
# 3   471             77
# 4   622             92
# 5   260             53
# 6   646             99
# 7   209            104
# 8   604            107
# 9   579             88
# 10  164             61
# 11  226             69
# 12  681             81
# 13  156             72
# 14  145             93
# 15  304            101
# 16  357             98
# 17  798            106
# 18  730             46
# 19  798             55
# 20   72            102
# 21  674             97
# 22  260             45
# 23  368             91
# 24  520             56
# 25  143             87
# 26  445             38
# 27  175             64
# 28  584             95
# 29  575             84
# 30  381             66
# ⋮   ⋮              ⋮
# 79   956           74
# 80   380           14
# 81   228           22
# 82   170           35
# 83   114            9
# 84    95           43
# 85    97           16
# 86   119           21
# 87   116           71
# 88  1044           10
# 89   171            6
# 90   426            8
# 91   271            4
# 92   233            5
# 93   221           28
# 94   201           19
# 95   537            2
# 96   209            7
# 97   166           20
# 98   293           25
# 99   305            3
# 100  430            1
# 101 1789           18
# 102  229           15
# 103  812           11
# 104  121           24
# 105 2044           26
# 106  925           23
# 107  507           12
# 108   70           17

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la  optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% PARAM$train_final]
dataset_train[,.N,clase_ternaria]
# Out:
#   clase_ternaria N
# 1 CONTINUA       161181
# 2 BAJA+2           1139
# 3 BAJA+1            964

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain_final <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 911341
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] -0.007955436
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] -1.335709
#
# $lambda_l2
# [1] -2.996427
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 1
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $early_stopping_rounds
# [1] 200
#
# $num_iterations
# [1] 685
#
# $learning_rate
# [1] 0.01036975
#
# $feature_fraction
# [1] 0.4656955
#
# $num_leaves
# [1] 238
#
# $min_data_in_leaf
# [1] 229

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria y mucho menos cross validation.

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

param_normalizado$early_stopping_rounds <- NULL

# %%
# entreno LightGBM

modelo_final <- lgb.train(
  data= dtrain_final,
  param= param_normalizado
)
# Out:
# Error in data$construct(): Check failed: (lambda_l1) >= (0.0) at io/config_auto.cpp, line 415 .
#
#
# Traceback:
#
# 1. data$construct()
# 2. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "Check failed: (lambda_l1) >= (0.0) at io/config_auto.cpp, line 415 .\n\n",
#  .     base::quote(data$construct()))

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...
lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes %in% PARAM$future]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion
tb_prediccion <- dfuture[, list(numero_de_cliente, foto_mes,clase_ternaria)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion[,list(numero_de_cliente,foto_mes,prob)],
  file= "prediccion.txt",
  sep= "\t"
)

# %%
# Dibujo la curva de ganancia acumulada
setorder(tb_prediccion,-prob)

tb_prediccion[, gan := ifelse(clase_ternaria == "BAJA+2", 1072500, -27500)]
tb_prediccion[, ganancia_acumulada := cumsum(gan)]
tb_prediccion[, pos := sequence(.N)]

# %%
tb_prediccion |> head()

# %%
# defino hasta donde muestra el grafico
amostrar <- 30000

# %%
require("ggplot2")

# %%
# observamos la curva de ganancia
gra <- ggplot(
           data= tb_prediccion[pos <= amostrar],
           aes( x= pos, y= ganancia_acumulada)
             ) + geom_line()

gra <- gra + theme(text = element_text(size = 16))

options(repr.plot.width=16, repr.plot.height=9)
print( gra )

# %% [markdown]
# Revisamos ganancia bajo distintos cortes

# %%
# inicilizo el dataset  drealidad
drealidad <- realidad_inicializar( dfuture, PARAM)

# %%
PARAM$cortes

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

for (envios in PARAM$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marco los primeros

  res <- realidad_evaluar( drealidad, tb_prediccion)

  options(scipen = 999)
  cat( "Envios=", envios, "\t",
    " TOTAL=", res$total,
    "  Public=", res$public,
    " Private=", res$private,
    "\n",
    sep= ""
  )

}

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
